# %%
import pandas as pd

# %%
# load csv file
df =pd.read_excel('bribe_reasons 2019.xlsx')

# create a data frame
df = pd.DataFrame(df)
df.head()
# Out:
#      State  population  prevalence in %
# 0     Abia     9401288         0.272251
# 1  Adamawa     9113605         0.406807
# 2     Akwa     6113503         0.309125
# 3  Anambra     5801584         0.238095
# 4   Bauchi     5591589         0.244211

# %% [markdown]
# ##Data cleaning

# %%
#Dropping unnecessary columns
stats =stats.drop(columns='state_id')

# %%
#Standardization. I need all column names to be written in lowercase.
lower_case(method)
lower_case(reason)
lower_case(time) 
lower_case(stats) 
lower_case(bribes)

# %%
#checking for null values per column
#create a function
def null(data):
  print(data.isnull().any())
  print(data.isnull().sum())

# %%
null(corrupt_officials)
# Out:
# state                                                                                   False
# police_officers                                                                          True
# judges/magistrates_at_the_court                                                          True
# prosecutors                                                                              True
# judges/magistrates_at_the_court/prosecutors                                              True
# tax/revenues_officers                                                                    True
# customs_officers                                                                         True
# public_utilities_officers                                                                True
# doctors                                                                                  True
# nurses                                                                                   True
# doctors/nurses                                                                           True
# teacher/lecturers                                                                        True
# car_registration/driving_license_agency_officers                                         True
# officials_from_traffic_management_authority                                              True
# members_of_the_armed_forces                                                              True
# land_registry_officers                                                                   True
# elected_representatives_from_local/state_government                                      True
# members_of_parliament/legislature                                                        True
# elected_representatives_from_local/state_governmentmembers_of_parliament/legislature     True
# immigration_service_officers                                                             True
# embassy/consulate_officers_of_foreign_countries                                          True
# other_public_official/civil_servant                                                      True
# total_public_officials                                                                   True
# year                                                                                    False
# region                                                                                   True
# sample_size                                                                              True
# population                                                                               True
# doctors,_nurses,_midwives                                                                True
# federal_road_safety_corps                                                                True
# vehicle_inspection_officers                                                              True
# other_health_workers                                                                     True
# dtype: bool
# state                                                                                    0
# police_officers                                                                          1
# judges/magistrates_at_the_court                                                          1
# prosecutors                                                                              1
# judges/magistrates_at_the_court/prosecutors                                             38
# tax/revenues_officers                                                                    1
# customs_officers                                                                        38
# public_utilities_officers                                                                1
# doctors                                                                                 38
# nurses                                                                                  38
# doctors/nurses                                                                          38
# teacher/lecturers                                                                        1
# car_registration/driving_license_agency_officers                                        38
# officials_from_traffic_management_authority                                             38
# members_of_the_armed_forces                                                              1
# land_registry_officers                                                                   1
# elected_representatives_from_local/state_government                                      1
# members_of_parliament/legislature                                                        1
# elected_representatives_from_local/state_governmentmembers_of_parliament/legislature    38
# immigration_service_officers                                                             1
# embassy/consulate_officers_of_foreign_countries                                          1
# other_public_official/civil_servant                                                      1
# total_public_officials                                                                  39
# year                                                                                     0
# region                                                                                  38
# sample_size                                                                             38
# population                                                                               1
# doctors,_nurses,_midwives                                                               38
# federal_road_safety_corps                                                               38
# vehicle_inspection_officers                                                             38
# other_health_workers                                                                    38
# dtype: int64

# %%
#checking for duplicates
def dup(d):
  print(d.duplicated().any())

# %%
dup(corrupt_officials)
dup(stats)

# %% [markdown]
# ##Data Wrangling

# %%
#create a new column prevalence by multiplying  population by prevalence in %
df['prevalence'] = df['population'] * df['prevalence in %']


df.head()
# Out:
#      State  population  prevalence in %    prevalence
# 0     Abia     9401288         0.272251  2.559513e+06
# 1  Adamawa     9113605         0.406807  3.707480e+06
# 2     Akwa     6113503         0.309125  1.889835e+06
# 3  Anambra     5801584         0.238095  1.381330e+06
# 4   Bauchi     5591589         0.244211  1.365525e+06

# %%
# Create new columns on reasons for bribing with prevalence per state as values
def new_col(x,z):
  df[x]= df['prevalence']*z

new_col('unemployment',0.17)
new_col('Crime and insecurity',0.17)
new_col('Health care',0.10)
new_col('Housing',0.07)
new_col('Corruption',0.14)
new_col('high cost of living',0.17)
new_col('infrastructure',0.12)
new_col('education',0.05)
new_col('political instability',0.03)
new_col('Ethnic or communal conflict',0.02)
new_col('Drug abuse and drug trafficking',0.01)
new_col('Environmental degradation',0.0)
new_col('Other problem',0.0)


df.head()
# Out:
#      State  population  ...  Environmental degradation  Other problem
# 0     Abia     9401288  ...                        0.0            0.0
# 1  Adamawa     9113605  ...                        0.0            0.0
# 2     Akwa     6113503  ...                        0.0            0.0
# 3  Anambra     5801584  ...                        0.0            0.0
# 4   Bauchi     5591589  ...                        0.0            0.0
#
# [5 rows x 17 columns]

# %%
df1 =pd.read_excel('bribes_reasons 2016.xlsx.xlsx')

#create a dataframe
df1= pd.DataFrame(df)


#multiply population by prevalence in %
df1['prevalence'] = df1['population'] * df1['prevalence in %']


df1.head()
# Out:
#      State  population  ...  Environmental degradation  Other problem
# 0     Abia     9401288  ...                        0.0            0.0
# 1  Adamawa     9113605  ...                        0.0            0.0
# 2     Akwa     6113503  ...                        0.0            0.0
# 3  Anambra     5801584  ...                        0.0            0.0
# 4   Bauchi     5591589  ...                        0.0            0.0
#
# [5 rows x 17 columns]

# %%
# make  the columns uniform
def lower_case(x):
  x.columns = x.columns.str.lower().str.replace(' ','_')
df1.head()
# Out:
#      State  population  ...  Environmental degradation  Other problem
# 0     Abia     9401288  ...                        0.0            0.0
# 1  Adamawa     9113605  ...                        0.0            0.0
# 2     Akwa     6113503  ...                        0.0            0.0
# 3  Anambra     5801584  ...                        0.0            0.0
# 4   Bauchi     5591589  ...                        0.0            0.0
#
# [5 rows x 17 columns]

# %%
#load corruption statistics dataset
corruption_stat =pd.read_excel('CorruptionStatistics_by_State_full.xlsx', sheet_name=0)
corruption_stat.head()

# create a dataframe
df=pd.DataFrame(corruption_stat)
df.head()
# Out:
#    STATE_ID     STATE  ... Total number of bribes paid  Average bribe size NGN
# 0         8     Borno  ...                     3769553                 2511.21
# 1        21     Kebbi  ...                     6805722                 5453.19
# 2        34    Taraba  ...                     7819059                 7433.97
# 3        36   Zamfara  ...                     9727426                 1466.77
# 4        25  Nasarawa  ...                     3292802                 4833.20
#
# [5 rows x 33 columns]

# %%
# make the columns uniform
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')
print(df)
# Out:
#     state_id      state  ... total_number_of_bribes_paid  average_bribe_size_ngn
# 0          8      Borno  ...                     3769553                 2511.21
# 1         21      Kebbi  ...                     6805722                 5453.19
# 2         34     Taraba  ...                     7819059                 7433.97
# 3         36    Zamfara  ...                     9727426                 1466.77
# 4         25   Nasarawa  ...                     3292802                 4833.20
# 5          2    Adamawa  ...                     2396296                 6611.72
# 6         28       Ondo  ...                    14043702                 2987.80
# 7         30        Oyo  ...                     6384121                 4097.83
# 8          9    C/river  ...                     2711354                10850.95
# 9         32     Rivers  ...                     5719161                 9943.00
# 10        33     Sokoto  ...                     4407084                 3043.25
# 11        12        Edo  ...                     4209953                 2465.76
# 12         7      Benue  ...                    13611543                 1675.86
# 13         1       Abia  ...                     2157775                 4631.30
# 14        18     Kaduna  ...                     4220873                 6322.88
# 15        24      Lagos  ...                    11212873                 3208.62
# 16         6    Bayelsa  ...                     1028836                36163.81
# 17        10      Delta  ...                    13687180                 3445.72
# 18        27       Ogun  ...                     3546157                 3767.03
# 19        22       Kogi  ...                     2340598                 2581.49
# 20        15      Gombe  ...                     1725532                 5172.74
# 21        19       Kano  ...                     7177366                 4740.26
# 22        31    Plateau  ...                     4193388                 5338.92
# 23        37        FCT  ...                     2452377                 9088.19
# 24         4    Anambra  ...                     4130528                34444.26
# 25        17     Jigawa  ...                     2839438                 2918.21
# 26        20    Katsina  ...                     5307236                 3625.24
# 27        13      Ekiti  ...                     4024125                 1529.58
# 28        14      Enugu  ...                     2655349                 5431.98
# 29        16        Imo  ...                     1605010                 6095.34
# 30        26      Niger  ...                     3444917                 2746.27
# 31         5     Bauchi  ...                     3302115                 3611.36
# 32        35       Yobe  ...                      810314                 3613.75
# 33        11     Ebonyi  ...                     2254643                 9573.36
# 34         3  Akwa-ibom  ...                     1821779                 6773.77
# 35        29       Osun  ...                     2636430                 1752.59
# 36        23      Kwara  ...                      589816                 3792.45
#
# [37 rows x 33 columns]

# %% [markdown]
# ## 1.	To investigate the states more acutely impacted by corruption.

# %%
#select the state and prevalence_of_bribery
prevalence_by_state=df [['state', 'prevalence_of_bribery']]
# sort the vales the data in descending order
prevalence_by_state.sort_values(by = 'prevalence_of_bribery', ascending= False, inplace= False)
# Out:
#         state  prevalence_of_bribery
# 0       Borno                  0.524
# 1       Kebbi                  0.517
# 2      Taraba                  0.510
# 3     Zamfara                  0.504
# 4    Nasarawa                  0.455
# 5     Adamawa                  0.453
# 6        Ondo                  0.421
# 7         Oyo                  0.401
# 9      Rivers                  0.400
# 8     C/river                  0.400
# 10     Sokoto                  0.383
# 11        Edo                  0.376
# 12      Benue                  0.368
# 13       Abia                  0.358
# 14     Kaduna                  0.356
# 15      Lagos                  0.351
# 16    Bayelsa                  0.349
# 17      Delta                  0.335
# 18       Ogun                  0.334
# 19       Kogi                  0.323
# 20      Gombe                  0.308
# 21       Kano                  0.306
# 22    Plateau                  0.286
# 23        FCT                  0.285
# 24    Anambra                  0.270
# 25     Jigawa                  0.265
# 26    Katsina                  0.265
# 27      Ekiti                  0.262
# 28      Enugu                  0.217
# 29        Imo                  0.214
# 30      Niger                  0.204
# 31     Bauchi                  0.200
# 32       Yobe                  0.194
# 33     Ebonyi                  0.187
# 34  Akwa-ibom                  0.181
# 35       Osun                  0.172
# 36      Kwara                  0.130

# %% [markdown]
# ##	To find out the people committing what offence are more likely to offer bribes.

# %%
# sum columns
df1
Totals=df1.iloc[:,4:16].sum()
Totals
Totals.sort_values(ascending = False)
# Out:
# high cost of living                7.424741e+06
# Crime and insecurity               7.424741e+06
# unemployment                       7.424741e+06
# Corruption                         6.114492e+06
# infrastructure                     5.240994e+06
# Health care                        4.367495e+06
# Housing                            3.057246e+06
# education                          2.183747e+06
# political instability              1.310248e+06
# Ethnic or communal conflict        8.734989e+05
# Drug abuse and drug trafficking    4.367495e+05
# Environmental degradation          0.000000e+00
# dtype: float64

# %% [markdown]
# ##	To find out whether there is a relationship between the average income and average bribe size per state.

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
corruption_stat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 33 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   state_id                                                                  37 non-null     int64
#  1   state                                                                     37 non-null     object
#  2   region                                                                    37 non-null     object
#  3   sample_size                                                               37 non-null     int64
#  4   population                                                                37 non-null     int64
#  5   rural_population                                                          37 non-null     int64
#  6   urban_population                                                          37 non-null     int64
#  7   male_population                                                           37 non-null     int64
#  8   female_population                                                         37 non-null     int64
#  9   share_rural_population                                                    37 non-null     float64
#  10  share_urban_population                                                    37 non-null     float64
#  11  share_male                                                                37 non-null     float64
#  12  share_female                                                              37 non-null     float64
#  13  n_people_who_had_contact                                                  37 non-null     int64
#  14  n_people_who_paid_or_refused_to_pay_a_bribe_(d2_and/or_d18_=_1)           37 non-null     int64
#  15  n_people_who_paid_a_bribe_(d2=1)                                          37 non-null     int64
#  16  n_people_who_paid_a_bribe_(d2=1)_and_specified_how_many_bribes_were_paid  37 non-null     int64
#  17  contact_rate_a                                                            37 non-null     float64
#  18  prevalence_of_bribery                                                     37 non-null     float64
#  19  avg_number_of_bribes_paid_by_bribe_payers                                 37 non-null     float64
#  20  n_of_bribes_paid_per_capita                                               37 non-null     float64
#  21  share_cash_payments                                                       37 non-null     float64
#  22  average_bribe_size_ngn_no_outliers                                        37 non-null     float64
#  23  average_bribe_size_$_ppp                                                  37 non-null     float64
#  24  reported_(at_least)_to_official_authority                                 37 non-null     float64
#  25  reported_to_official_authority_or_non-official_institution                37 non-null     float64
#  26  did_not_report                                                            37 non-null     float64
#  27  average_income                                                            37 non-null     float64
#  28  share_of_mention_of_corruption_among_one_of_the_3_most_important_issues   37 non-null     float64
#  29  share_of_mention_of_corruption_as_the_most_important_issues               37 non-null     float64
#  30  prevalence_of_bribery_police                                              37 non-null     float64
#  31  total_number_of_bribes_paid                                               37 non-null     int64
#  32  average_bribe_size_ngn                                                    37 non-null     float64
# dtypes: float64(19), int64(12), object(2)
# memory usage: 9.7+ KB

# %%
#change the average_income column to int
df.col = df.average_income.astype(int)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access

# %%
#select income column and number of bribes column
corruption_subset = corruption_stat[['average_bribe_size_ngn','average_income']]
corruption_subset.head()
# Out:
#    average_bribe_size_ngn  average_income
# 0                 2511.21        26027.95
# 1                 5453.19        23282.19
# 2                 7433.97        29208.77
# 3                 1466.77        26796.25
# 4                 4833.20        46630.74

# %%
# set average_income as the independent variable and total_number_of_bribes_paid as the dependent variable
y = corruption_subset['average_bribe_size_ngn']
x1= corruption_subset['average_income']

# %%
# create a scatter plot
plt.scatter(x1, y)
plt.xlabel('average_income', fontsize= 20)
plt.ylabel('average_bribe_size_ngn', fontsize= 20)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#We noticed the two data points of average bribe size further away from the rest
Q1 = corruption_subset['average_income'].quantile(0.25)
Q3 = corruption_subset['average_income'].quantile(0.75)
IQR = Q3-Q1

without_outliers = corruption_subset[~((corruption_subset['average_income']< Q1-1.5*IQR) | (corruption_subset['average_income']> Q3+1.5*IQR))]
print(without_outliers.shape)
print(corruption_subset.shape)
# Out:
# (34, 2)
# (37, 2)

# %%
#create a regression model
x = sm.add_constant(x1)
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     average_bribe_size_ngn   R-squared:                       0.007
# Model:                                OLS   Adj. R-squared:                 -0.021
# Method:                     Least Squares   F-statistic:                    0.2469
# Date:                    Wed, 18 Aug 2021   Prob (F-statistic):              0.622
# Time:                            13:36:31   Log-Likelihood:                -381.61
# No. Observations:                      37   AIC:                             767.2
# Df Residuals:                          35   BIC:                             770.4
# Df Model:                               1
# Covariance Type:                nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           4365.7013   4116.564      1.061      0.296   -3991.368    1.27e+04
# average_income     0.0654      0.132      0.497      0.622      -0.202       0.333
# ==============================================================================
# Omnibus:                       50.929   Durbin-Watson:                   2.159
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              231.557
# Skew:                           3.297   Prob(JB):                     5.22e-51
# Kurtosis:                      13.331   Cond. No.                     1.04e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.04e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#plot a regression line
plt.scatter(x1, y)
yhat = 31.05*x1 + 	3.778e+06
fig = plt.plot(yhat, x1, lw= 4, c= 'orange', label= 'regression line')
plt.xlabel('average_income', fontsize =20)
plt.ylabel('total_number_number_bribes_paid', fontsize = 20)
# Out:
# Text(0, 0.5, 'total_number_number_bribes_paid')

# %% [markdown]
# #Corrupt Officials Analysis
# ##Data Consolidation

# %%
#loading the first sheet on our excel workbook
populas = pd.read_excel('Book1.xlsx', sheet_name= 0)

#loading the second sheet in our excel workbook
public_officials =pd.read_excel('Book1.xlsx', sheet_name=1)

# %%
#The function when called should return the shape, information and the first 5 rows of our dataset.
def information(d):
  print(d.shape)
  print(d.info())

# %%
#The shape, information and first five rows of public offices dataset
information(public_officials)
# Out:
# (38, 24)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 24 columns):
#  #   Column                                                                                Non-Null Count  Dtype
# ---  ------                                                                                --------------  -----
#  0   Unnamed: 0                                                                            38 non-null     object
#  1   Police officers                                                                       38 non-null     float64
#  2   Judges/Magistrates at the court                                                       38 non-null     float64
#  3   Prosecutors                                                                           38 non-null     float64
#  4   Judges/Magistrates at the court/Prosecutors                                           38 non-null     float64
#  5   Tax/revenues officers                                                                 38 non-null     float64
#  6   Customs officers                                                                      38 non-null     float64
#  7   Public utilities officers                                                             38 non-null     float64
#  8   Doctors                                                                               38 non-null     float64
#  9   Nurses                                                                                38 non-null     float64
#  10  Doctors/Nurses                                                                        38 non-null     float64
#  11  Teacher/Lecturers                                                                     38 non-null     float64
#  12  Car registration/driving license agency officers                                      38 non-null     float64
#  13  Officials from Traffic Management Authority                                           38 non-null     float64
#  14  Members of the Armed forces                                                           38 non-null     float64
#  15  Land registry officers                                                                38 non-null     float64
#  16  Elected representatives from Local/State government                                   38 non-null     float64
#  17  Members of Parliament/Legislature                                                     38 non-null     float64
#  18  Elected representatives from Local/State governmentMembers of Parliament/Legislature  38 non-null     float64
#  19  Immigration Service officers                                                          38 non-null     float64
#  20  Embassy/consulate officers of foreign countries                                       38 non-null     float64
#  21  Other public official/civil servant                                                   38 non-null     float64
#  22  Total public officials                                                                38 non-null     float64
#  23  Year                                                                                  38 non-null     int64
# dtypes: float64(22), int64(1), object(1)
# memory usage: 7.2+ KB
# None

# %%
#Information on pop dataset i.e. shape, info and first few rows.
information(populas)
# Out:
# (37, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   STATE_ID     37 non-null     int64
#  1   STATE        37 non-null     object
#  2   Region       37 non-null     object
#  3   Sample size  37 non-null     int64
#  4   Population   37 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 1.6+ KB
# None

# %%
#Replacing the column heading unnamed to state, it's in capital to match column heading state in public offices dataset
public_officials.columns =public_officials.columns.str.replace('Unnamed: 0', 'STATE')

# %%
public_officials.head()
# Out:
#        STATE  Police officers  ...  Total public officials  Year
# 0       Abia         0.440299  ...                   0.358  2016
# 1    Adamawa         0.588889  ...                   0.453  2016
# 2  Akwa-ibom         0.253164  ...                   0.181  2016
# 3    Anambra         0.527273  ...                   0.270  2016
# 4     Bauchi         0.375000  ...                   0.200  2016
#
# [5 rows x 24 columns]

# %%
# The function should lower the case of the columns referred to an replace the space with an underscore.
def lower_case(x):
  x.columns = x.columns.str.lower().str.replace(' ','_')

# %%
#Lowering and replacing the space with underscore of the columns in the two datasets.
lower_case(populas)
lower_case(public_officials)

# %%
#merging the two datasets on column state
public_officials = public_officials.merge( populas,how ="left",on ='state')
public_officials.head()
# Out:
#        state  police_officers  ...  sample_size  population
# 0       Abia         0.440299  ...        900.0   3616382.0
# 1    Adamawa         0.588889  ...        779.0   4111706.0
# 2  Akwa-ibom         0.253164  ...        900.0   5272029.0
# 3    Anambra         0.527273  ...        900.0   5356592.0
# 4     Bauchi         0.375000  ...        891.0   6286719.0
#
# [5 rows x 28 columns]

# %%
#dropping the column state_id
pop = public_officials.drop('state_id', axis=1)

# %%
#defining a function replace_percentage. The function takes the parameters dst- dataset and col- column. It multiplies the percentage values in the columns and multiplies
#with the population of that state, the replaces the percentage value with the value computated.This is because we want to obtained the population of people
#having stated to have come into contact with corrupt public officers.
def replace_percentage(dst,col):
  val = dst[col].values
  num = dst['population']
  dst[col] = dst[col].replace(to_replace= val, value= val*num)

# %%
#In the next three cells, the function is called and the computation done to all columns with percentages 
replace_percentage(pop,'police_officers')

# %%
replace_percentage(pop,'judges/magistrates_at_the_court')
replace_percentage(pop,'prosecutors')
replace_percentage(pop,'judges/magistrates_at_the_court/prosecutors')
replace_percentage(pop,'tax/revenues_officers')
replace_percentage(pop,'customs_officers')
replace_percentage(pop,'public_utilities_officers')
replace_percentage(pop,'doctors')
replace_percentage(pop,'nurses')
replace_percentage(pop,'doctors/nurses')
replace_percentage(pop,'teacher/lecturers')
replace_percentage(pop,'car_registration/driving_license_agency_officers')
replace_percentage(pop,'officials_from_traffic_management_authority')
replace_percentage(pop,'members_of_the_armed_forces')
replace_percentage(pop,'land_registry_officers')
replace_percentage(pop,'elected_representatives_from_local/state_government')
replace_percentage(pop,'members_of_parliament/legislature')
replace_percentage(pop,'elected_representatives_from_local/state_governmentmembers_of_parliament/legislature')
replace_percentage(pop,'immigration_service_officers')
replace_percentage(pop,'embassy/consulate_officers_of_foreign_countries')
replace_percentage(pop,'other_public_official/civil_servant')
replace_percentage(pop,'total_public_officials')

# %%
#On viewing the dataset we notice that the float value is in standard form.
pop
# Out:
#         state  police_officers  ...  sample_size  population
# 0        Abia     1.592288e+06  ...        900.0   3616382.0
# 1     Adamawa     2.421338e+06  ...        779.0   4111706.0
# 2   Akwa-ibom     1.334689e+06  ...        900.0   5272029.0
# 3     Anambra     2.824385e+06  ...        900.0   5356592.0
# 4      Bauchi     2.357521e+06  ...        891.0   6286719.0
# 5     Bayelsa     1.081126e+06  ...        900.0   2204648.0
# 6       Benue     3.207625e+06  ...        895.0   5550037.0
# 7       Borno     3.127725e+06  ...        900.0   5635544.0
# 8     C/river     2.461742e+06  ...        886.0   3741838.0
# 9       Delta     2.954551e+06  ...        900.0   5460311.0
# 10     Ebonyi     6.876782e+05  ...        900.0   2791167.0
# 11        Edo     1.392363e+06  ...        900.0   4109499.0
# 12      Ekiti     1.337124e+06  ...        900.0   3157552.0
# 13      Enugu     1.887248e+06  ...        896.0   4263786.0
# 14      Gombe     2.107794e+06  ...        899.0   3140189.0
# 15        Imo     1.588625e+06  ...        900.0   5214833.0
# 16     Jigawa     3.053165e+06  ...        884.0   5640592.0
# 17     Kaduna     4.823142e+06  ...        892.0   7976735.0
# 18       Kano     6.404486e+06  ...        900.0  12591871.0
# 19    Katsina     3.498144e+06  ...        900.0   7569751.0
# 20      Kebbi     2.755488e+06  ...        900.0   4286319.0
# 21       Kogi     1.640756e+06  ...        896.0   4324074.0
# 22      Kwara     9.077203e+05  ...        900.0   3086249.0
# 23      Lagos     3.903424e+06  ...        886.0  12100616.0
# 24   Nasarawa     1.144275e+06  ...        900.0   2439113.0
# 25      Niger     1.436134e+06  ...        881.0   5343260.0
# 26       Ogun     1.674732e+06  ...        894.0   5024191.0
# 27       Ondo     2.935178e+06  ...        900.0   4515660.0
# 28       Osun     1.376861e+06  ...        900.0   4536877.0
# 29        Oyo     4.591853e+06  ...        900.0   7540300.0
# 30    Plateau     1.675861e+06  ...        898.0   4075392.0
# 31     Rivers     4.121486e+06  ...        899.0   7023942.0
# 32     Sokoto     3.019470e+06  ...        900.0   4831152.0
# 33     Taraba     1.592899e+06  ...        897.0   2968132.0
# 34       Yobe     9.525259e+05  ...        898.0   3163747.0
# 35    Zamfara     2.346586e+06  ...        896.0   4353533.0
# 36        FCT     1.138432e+06  ...        900.0   3130694.0
# 37    NIGERIA              NaN  ...          NaN         NaN
#
# [38 rows x 27 columns]

# %%
# rounding off the computed values to one decimal place.
pop.iloc[:, 1:23] = round(pop.iloc[:, 1:23])

# %%
# Upon viewing the dataset, the values have been rounded off.
pop.head()
# Out:
#        state  police_officers  ...  sample_size  population
# 0       Abia        1592288.0  ...        900.0   3616382.0
# 1    Adamawa        2421338.0  ...        779.0   4111706.0
# 2  Akwa-ibom        1334689.0  ...        900.0   5272029.0
# 3    Anambra        2824385.0  ...        900.0   5356592.0
# 4     Bauchi        2357521.0  ...        891.0   6286719.0
#
# [5 rows x 27 columns]

# %%
#Loading sheet 3 in the excel workbook
twenty_nineteen = pd.read_excel('/content/Book1.xlsx', sheet_name= 3)
twenty_nineteen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 20 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   state                                           37 non-null     object
#  1   population                                      37 non-null     int64
#  2   Doctors, Nurses, Midwives                       37 non-null     float64
#  3   Police officers                                 37 non-null     float64
#  4   Public utility officers                         37 non-null     float64
#  5   Teachers/Lecturers                              37 non-null     float64
#  6   Federal Road Safety Corps                       37 non-null     float64
#  7   Vehicle inspection officers                     37 non-null     float64
#  8   Elected local/state government representatives  37 non-null     float64
#  9   Members of the Armed Forces                     37 non-null     float64
#  10  Tax/Revenue officers                            37 non-null     float64
#  11  Customs/Immigration officers                    37 non-null     float64
#  12  Members of Parliament/Legislature               37 non-null     float64
#  13  Land registry officers                          37 non-null     float64
#  14  Judges/Magistrates                              37 non-null     float64
#  15  Prosecutors                                     37 non-null     float64
#  16  Embassy/Consulate officers                      37 non-null     float64
#  17  Other health workers                            37 non-null     float64
#  18  Other public official                           37 non-null     float64
#  19  Year                                            37 non-null     int64
# dtypes: float64(17), int64(2), object(1)
# memory usage: 5.9+ KB

# %%
#Lowering the case of the column names and replacing spaces with an underscore.
lower_case(twenty_nineteen)

# %%
#In the next few cells, we compared the rows of the two datasets as we intend to concat. The columns that display information on similar public offices had to
# have the same name and hence we replaced the named of a lot of columns.
twenty_nineteen.columns
# Out:
# Index(['state', 'population', 'doctors,_nurses,_midwives', 'police_officers',
#        'public_utility_officers', 'teachers/lecturers',
#        'federal_road_safety_corps', 'vehicle_inspection_officers',
#        'elected_local/state_government_representatives',
#        'members_of_the_armed_forces', 'tax/revenue_officers',
#        'customs/immigration_officers', 'members_of_parliament/legislature',
#        'land_registry_officers', 'judges/magistrates', 'prosecutors',
#        'embassy/consulate_officers', 'other_health_workers',
#        'other_public_official', 'year'],
#       dtype='object')

# %%
pop.columns
# Out:
# Index(['state', 'police_officers', 'judges/magistrates_at_the_court',
#        'prosecutors', 'judges/magistrates_at_the_court/prosecutors',
#        'tax/revenues_officers', 'customs_officers',
#        'public_utilities_officers', 'doctors', 'nurses', 'doctors/nurses',
#        'teacher/lecturers', 'car_registration/driving_license_agency_officers',
#        'officials_from_traffic_management_authority',
#        'members_of_the_armed_forces', 'land_registry_officers',
#        'elected_representatives_from_local/state_government',
#        'members_of_parliament/legislature',
#        'elected_representatives_from_local/state_governmentmembers_of_parliament/legislature',
#        'immigration_service_officers',
#        'embassy/consulate_officers_of_foreign_countries',
#        'other_public_official/civil_servant', 'total_public_officials', 'year',
#        'region', 'sample_size', 'population'],
#       dtype='object')

# %%
twenty_nineteen.columns = twenty_nineteen.columns.str.replace('elected_local/state_government_representatives','elected_representatives_from_local/state_government')

# %%
#The function was created for replacing column names. It's parameters were a- dataset, b- old name, c-new name
def replace(a,b,c):
  a.columns = a.columns.str.replace(b,c)

# %%
replace(twenty_nineteen,'judges/magistrates','judges/magistrates_at_the_court')
replace(twenty_nineteen,'embassy/consulate_officers','embassy/consulate_officers_of_foreign_countries')
replace(twenty_nineteen,'other_public_official','other_public_official/civil_servant')
replace(twenty_nineteen,'customs/immigration_officers','immigration_service_officers')
replace(twenty_nineteen,'teachers/lecturers','teacher/lecturers')
replace(twenty_nineteen,'public_utility_officers','public_utilities_officers')
replace(twenty_nineteen,'tax/revenue_officers','tax/revenues_officers')

# %%
# On viewing the dataset, the names had been changed.
twenty_nineteen.tail()
# Out:
#       state  population  ...  other_public_official/civil_servant  year
# 32   Rivers     2300736  ...                             0.090833  2019
# 33   Sokoto     2173501  ...                             0.090833  2019
# 34   Taraba     1863275  ...                             0.090833  2019
# 35     Yobe     1703358  ...                             0.090833  2019
# 36  Zamfara     4194080  ...                             0.090833  2019
#
# [5 rows x 20 columns]

# %%
#The replace_percentage function was used again to replace percentage with population values for dataset twenty_nineteen
replace_percentage(twenty_nineteen,'doctors,_nurses,_midwives')
replace_percentage(twenty_nineteen,'police_officers')
replace_percentage(twenty_nineteen,'public_utilities_officers')
replace_percentage(twenty_nineteen,'teacher/lecturers')
replace_percentage(twenty_nineteen,'federal_road_safety_corps')
replace_percentage(twenty_nineteen,'vehicle_inspection_officers')
replace_percentage(twenty_nineteen,'elected_representatives_from_local/state_government')
replace_percentage(twenty_nineteen,'members_of_the_armed_forces')
replace_percentage(twenty_nineteen,'tax/revenues_officers')
replace_percentage(twenty_nineteen,'immigration_service_officers')
replace_percentage(twenty_nineteen,'members_of_parliament/legislature')
replace_percentage(twenty_nineteen,'land_registry_officers')
replace_percentage(twenty_nineteen,'judges/magistrates_at_the_court')
replace_percentage(twenty_nineteen,'prosecutors')
replace_percentage(twenty_nineteen,'embassy/consulate_officers_of_foreign_countries')
replace_percentage(twenty_nineteen,'other_health_workers')
replace_percentage(twenty_nineteen,'other_public_official/civil_servant')

# %%
# The values were also rounded off as we expected them to be in standard form.
twenty_nineteen.iloc[:, 2:19] = round(twenty_nineteen.iloc[:, 2:19])

# %%
#Combining the two datasets
corrupt_officials =pd.concat([pop, twenty_nineteen], ignore_index=True)

# %%
#Displaying information on dataset corrupt_offcials, the concatenated dataset.
information(corrupt_officials)
# Out:
# (75, 31)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 31 columns):
#  #   Column                                                                                Non-Null Count  Dtype
# ---  ------                                                                                --------------  -----
#  0   state                                                                                 75 non-null     object
#  1   police_officers                                                                       74 non-null     float64
#  2   judges/magistrates_at_the_court                                                       74 non-null     float64
#  3   prosecutors                                                                           74 non-null     float64
#  4   judges/magistrates_at_the_court/prosecutors                                           37 non-null     float64
#  5   tax/revenues_officers                                                                 74 non-null     float64
#  6   customs_officers                                                                      37 non-null     float64
#  7   public_utilities_officers                                                             74 non-null     float64
#  8   doctors                                                                               37 non-null     float64
#  9   nurses                                                                                37 non-null     float64
#  10  doctors/nurses                                                                        37 non-null     float64
#  11  teacher/lecturers                                                                     74 non-null     float64
#  12  car_registration/driving_license_agency_officers                                      37 non-null     float64
#  13  officials_from_traffic_management_authority                                           37 non-null     float64
#  14  members_of_the_armed_forces                                                           74 non-null     float64
#  15  land_registry_officers                                                                74 non-null     float64
#  16  elected_representatives_from_local/state_government                                   74 non-null     float64
#  17  members_of_parliament/legislature                                                     74 non-null     float64
#  18  elected_representatives_from_local/state_governmentmembers_of_parliament/legislature  37 non-null     float64
#  19  immigration_service_officers                                                          74 non-null     float64
#  20  embassy/consulate_officers_of_foreign_countries                                       74 non-null     float64
#  21  other_public_official/civil_servant                                                   74 non-null     float64
#  22  total_public_officials                                                                36 non-null     float64
#  23  year                                                                                  75 non-null     int64
#  24  region                                                                                37 non-null     object
#  25  sample_size                                                                           37 non-null     float64
#  26  population                                                                            74 non-null     float64
#  27  doctors,_nurses,_midwives                                                             37 non-null     float64
#  28  federal_road_safety_corps                                                             37 non-null     float64
#  29  vehicle_inspection_officers                                                           37 non-null     float64
#  30  other_health_workers                                                                  37 non-null     float64
# dtypes: float64(28), int64(1), object(2)
# memory usage: 18.3+ KB
# None

# %%
corrupt_officials =round(corrupt_officials)
